# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-99f571c8-6884-4803-b3cf-43cc0eabd4e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99f571c8-6884-4803-b3cf-43cc0eabd4e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('credit_customers.csv')
df.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv         1169.0  no known savings        >=7
# 1             radio/tv         5951.0              <100     1<=X<4
# 2            education         2096.0              <100     4<=X<7
# 3  furniture/equipment         7882.0              <100     4<=X<7
# 4              new car         4870.0              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  ...  \
# 0                     4.0         male single          none  ...
# 1                     2.0  female div/dep/mar          none  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %% [markdown]
# #Análisis de nulos

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# checking_status           0
# property_magnitude        0
# foreign_worker            0
# own_telephone             0
# num_dependents            0
# job                       0
# existing_credits          0
# housing                   0
# other_payment_plans       0
# age                       0
# residence_since           0
# duration                  0
# other_parties             0
# personal_status           0
# installment_commitment    0
# employment                0
# savings_status            0
# credit_amount             0
# purpose                   0
# credit_history            0
# class                     0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
df.isna().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %% [markdown]
# # Variables categóricas

# %%
categorical=df.select_dtypes(include=object).columns
variables=categorical.drop('class')
for c in variables:
  print(c)
  print(df[c].unique())
# Out:
# checking_status
# ['<0' '0<=X<200' 'no checking' '>=200']
# credit_history
# ['critical/other existing credit' 'existing paid' 'delayed previously'
#  'no credits/all paid' 'all paid']
# purpose
# ['radio/tv' 'education' 'furniture/equipment' 'new car' 'used car'
#  'business' 'domestic appliance' 'repairs' 'other' 'retraining']
# savings_status
# ['no known savings' '<100' '500<=X<1000' '>=1000' '100<=X<500']
# employment
# ['>=7' '1<=X<4' '4<=X<7' 'unemployed' '<1']
# personal_status
# ['male single' 'female div/dep/mar' 'male div/sep' 'male mar/wid']
# other_parties
# ['none' 'guarantor' 'co applicant']
# property_magnitude
# ['real estate' 'life insurance' 'no known property' 'car']
# other_payment_plans
# ['none' 'bank' 'stores']
# housing
# ['own' 'for free' 'rent']
# job
# ['skilled' 'unskilled resident' 'high qualif/self emp/mgmt'
#  'unemp/unskilled non res']
# own_telephone
# ['yes' 'none']
# foreign_worker
# ['yes' 'no']

# %% [markdown]
# Se extrae el género de la columna personal_status porque no hay una similitud en los estados civiles disponibles en el dataset entre hombres y mujeres

# %%
df['sex']= df['personal_status'].str.extract(r'\b(male|female)\b')
df.drop(['personal_status'], axis=1, inplace = True)

# %% [markdown]
# Se eliminan los simbolos de >, < y = de las columnas ***checking_status*** ,***saving_status*** y ***employment*** para darle una mayor legibilidad a la base de datos y a los gráficos.

# %%
df['checking_status'].replace(['<0' ,'0<=X<200' , '>=200'],['less than 0','0 to 199','200 or more'], inplace=True)
df['savings_status'].replace(['<100', '500<=X<1000', '>=1000' ,'100<=X<500'],['less than 100','500 to 999', '100 to 499','1000 or more'], inplace=True)
df['employment'].replace(['>=7', '1<=X<4', '4<=X<7', '<1'],['7 or more','1 to 3', '4 to 6','less than 1'], inplace=True)

# %%
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
categorical=df.select_dtypes(include=object).columns
variables=categorical.drop('class')
categoric_titles=['Estado de la cuenta corriente','Historial crediticio del usuario','Propósito del crédito','Estado de la cuenta de ahorro',
                  'Años de empleo', 'Otros deudores', 'Propiedades','Otros planes de pago','Tipo de vivienda', 'Tipo de trabajo',
                  'Propietario de teléfono','Trabajador extranjero','Sexo']

num_plots = len(variables)
num_cols = 2
num_rows = (num_plots + 1) // num_cols

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 30))


for i, variable in enumerate(variables):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]
    sns.countplot(data=df, x=variable, ax=ax)
    ax.set_title(categoric_titles[i], fontsize=14)
    ax.set_xlabel(variable, fontsize=12)
    ax.set_ylabel('Count', fontsize=12)
    ax.tick_params(axis='x', rotation=45)

if num_plots < num_rows * num_cols:
    for i in range(num_plots, num_rows * num_cols):
        fig.delaxes(axes.flatten()[i])


plt.tight_layout()


plt.show()

# %%
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 30))
for i, variable in enumerate(variables):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    sns.countplot(data=df, y=variable, hue='class',palette = 'Set1' ,ax=ax)

    ax.set_title(categoric_titles[i], fontsize=14)
    ax.set_xlabel('class', fontsize=12)
    ax.set_ylabel('Count', fontsize=12)
    ax.legend(title=variable)

if num_plots < num_rows * num_cols:
    for i in range(num_plots, num_rows * num_cols):
        fig.delaxes(axes.flatten()[i])


plt.tight_layout()


plt.show()

# %%
df['class'].value_counts()
# Out:
# good    700
# bad     300
# Name: class, dtype: int64
